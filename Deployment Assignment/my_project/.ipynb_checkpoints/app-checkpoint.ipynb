# %%
print("Hello, World! This is my app.")
# Out:
# Hello, World! This is my app.

# %%
import streamlit as st

st.title("My First Streamlit App")
st.write("Hello from Streamlit!")
# Out:
# 2025-02-04 12:16:05.117 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 12:16:05.578
# ...
#   command:
#
#     streamlit run C:\Users\Gurbachan\miniconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-02-04 12:16:05.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 12:16:05.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 12:16:05.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 12:16:05.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 12:16:05.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
